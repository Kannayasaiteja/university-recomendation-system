# %%
import sys
import os
import collections
from collections import defaultdict
import numpy as np
import pandas as pd
from scipy import stats
import re

# %%
cs_file = r"D:\csp project\University_Recommendation_System-master\University_Recommendation_System-master\WebScraped_data\csv\Final.csv"
data = pd.read_csv(cs_file)
data.shape
# Out:
# C:\Users\saite\AppData\Local\Temp\ipykernel_18104\1542349310.py:2: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(cs_file)
# (485251, 20)

# %%
data.drop(data.columns[data.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
data.head()
# Out:
#                             0                                      1      2  \
# 0      University Of Waterloo             Systems Design Engineering     MS
# 1     Northeastern University                 Electrical Engineering    PhD
# 2  The University Of Auckland  Electrical And Electronic Engineering     MS
# 3          Radford University            Counseling Psychology PsyD.  Other
# 4    University Of Chittagong                       Computer Science     MS
#
#      3         4        5              6             7    8      9     10  \
# 0  NaN  Accepted  Website   (1, 7, 2019)  1.561964e+09  NaN    NaN    NaN
# 1  F19  Rejected  Website   (8, 7, 2019)  1.562569e+09  NaN    NaN    NaN
# 2  NaN  Accepted  Website  (19, 6, 2019)  1.560928e+09  NaN    NaN    NaN
# 3  F19  Accepted    Phone   (4, 3, 2019)  1.551686e+09  NaN    NaN    NaN
# 4  NaN       NaN    Other   (9, 7, 2019)  1.562656e+09  3.2  163.0  168.0
#
#     11    12  13             14             15          16  \
# 0  NaN   NaN NaN  International  (10, 7, 2019)  1562742000
# 1  NaN   NaN NaN            NaN  (10, 7, 2019)  1562742000
# 2  NaN   NaN NaN  International   (9, 7, 2019)  1562655600
# 3  NaN   NaN NaN       American   (9, 7, 2019)  1562655600
# 4  4.0  True NaN  International   (9, 7, 2019)  1562655600
#
#                                                   17
# 0                                                NaN
# 1                                   Got email today!
# 2  Top Student\nIELTS: 7.5\nContacted Supervisor\...
# 3                                                NaN
# 4                                                NaN

# %%
data.columns = ['univName', 'major', 'program', 'season', 'decision', 'Method', 'decdate', 'decdate_ts', 'cgpa', 'greV', 'greQ', 
           'greA', 'is_new_gre', 'gre_subject','status', 'post_data', 'post_timestamp', 'comments']
data.head()
# Out:
#                      univName                                  major program  \
# 0      University Of Waterloo             Systems Design Engineering      MS
# 1     Northeastern University                 Electrical Engineering     PhD
# 2  The University Of Auckland  Electrical And Electronic Engineering      MS
# 3          Radford University            Counseling Psychology PsyD.   Other
# 4    University Of Chittagong                       Computer Science      MS
#
#   season  decision   Method        decdate    decdate_ts  cgpa   greV   greQ  \
# 0    NaN  Accepted  Website   (1, 7, 2019)  1.561964e+09   NaN    NaN    NaN
# 1    F19  Rejected  Website   (8, 7, 2019)  1.562569e+09   NaN    NaN    NaN
# 2    NaN  Accepted  Website  (19, 6, 2019)  1.560928e+09   NaN    NaN    NaN
# 3    F19  Accepted    Phone   (4, 3, 2019)  1.551686e+09   NaN    NaN    NaN
# 4    NaN       NaN    Other   (9, 7, 2019)  1.562656e+09   3.2  163.0  168.0
#
#    greA is_new_gre  gre_subject         status      post_data  post_timestamp  \
# 0   NaN        NaN          NaN  International  (10, 7, 2019)      1562742000
# 1   NaN        NaN          NaN            NaN  (10, 7, 2019)      1562742000
# 2   NaN        NaN          NaN  International   (9, 7, 2019)      1562655600
# 3   NaN        NaN          NaN       American   (9, 7, 2019)      1562655600
# 4   4.0       True          NaN  International   (9, 7, 2019)      1562655600
#
#                                             comments
# 0                                                NaN
# 1                                   Got email today!
# 2  Top Student\nIELTS: 7.5\nContacted Supervisor\...
# 3                                                NaN
# 4                                                NaN

# %%
data = data[data['decision'] =='Accepted']

data.shape
# Out:
# (197059, 18)

# %%
data = data[pd.notnull(data['greQ'])]
data.shape
# Out:
# (61475, 18)

# %%
data['greQ'] = data['greQ'].fillna(130)
data['greV'] = data['greV'].fillna(130)
data['greA'] = data['greA'].fillna(0)
data.greA.head()
# Out:
# 7     4.0
# 14    3.0
# 17    5.5
# 28    4.0
# 46    4.0
# Name: greA, dtype: float64

# %%
uni_names = data['univName'].unique()

similar_univs = pd.DataFrame({'univName':uni_names})
similar_univs
# Out:
#                                              univName
# 0              New York University (NYU) - Steinhardt
# 1                               Ohio State University
# 2                                Texas A&M University
# 3                                St. Johns University
# 4                    University Of California, Irvine
# ...                                               ...
# 5317                         New York University(NYU)
# 5318                                 DeVry University
# 5319                                Oregon University
# 5320  University Of California, Santa Barbarba (UCSB)
# 5321                                     kalasalingam
#
# [5322 rows x 1 columns]

# %%
data.describe()
# Out:
#          decdate_ts          cgpa          greV          greQ          greA  \
# count  6.145500e+04  55590.000000  61475.000000  61475.000000  61475.000000
# mean   1.431528e+09      3.715968    231.555299    248.825165      4.144758
# std    9.558072e+07      0.506148    174.573915    208.550366      1.111117
# min   -1.000000e+00      0.400000    130.000000    130.000000      0.000000
# 25%    1.363244e+09      3.520000    155.000000    157.000000      3.500000
# 50%    1.426662e+09      3.750000    161.000000    164.000000      4.000000
# 75%    1.490771e+09      3.900000    167.000000    170.000000      5.000000
# max    1.360120e+10      9.990000    800.000000    800.000000      6.000000
#
#        gre_subject  post_timestamp
# count  7175.000000    6.147500e+04
# mean    796.411150    1.431741e+09
# std     122.305977    8.097374e+07
# min     310.000000    1.145458e+08
# 25%     710.000000    1.363417e+09
# 50%     800.000000    1.427094e+09
# 75%     890.000000    1.491030e+09
# max     990.000000    1.562569e+09

# %%
def convert_quant_score(quant_score):
    quant_list = []
    quant_score = quant_score.tolist()
    for old_quant in quant_score:
        if old_quant <= 170:
            quant_list.append(old_quant)
            continue
        else:
            old_quant = old_quant/4.7
            if old_quant <=130:
                quant_list.append(130)
            else:
                quant_list.append(old_quant)
    return quant_list

def convert_verbal_score(verbal_score):
    verbal_list = []
    verbal_score = verbal_score.tolist()
    for old_verbal in verbal_score:
        if old_verbal <= 170:
            verbal_list.append(old_verbal)
            continue
        else:
            old_verbal = old_verbal/4.7
            if old_verbal <=130:
                verbal_list.append(130)
            else:
                verbal_list.append(old_verbal)
    return verbal_list

data['greQ'] = convert_quant_score(data['greQ'])
data['greV'] = convert_verbal_score(data['greV'])

# %%
from matplotlib import pyplot as plt
import seaborn as sns
sns.pairplot(data, palette="husl", x_vars=["greV","cgpa","greQ"], y_vars=["greV","cgpa","greQ"], height=8)
plt.show()

# %%
def normalize_gpa(data2,cgpa,totalcgpa):
    cgpa = data2[cgpa].tolist()
    totalcgpa = data2[totalcgpa].tolist()
    for i in range(len(cgpa)):
        if totalcgpa[i] != 0:
            cgpa[i] = cgpa[i] / totalcgpa[i]
        else:
            cgpa[i] = 0
    data2['cgpa'] = cgpa
    return data2

# %%
data = data.drop('major',1)
data = data.drop('program',1)
data = data.drop('season',1)
data = data.drop('decision',1)
data = data.drop('Method',1)
data = data.drop('decdate',1)
data = data.drop('decdate_ts',1)
data = data.drop('is_new_gre',1)
data = data.drop('gre_subject',1)
data = data.drop('status',1)
data = data.drop('post_data',1)
data = data.drop('post_timestamp',1)
data = data.drop('comments',1)

university_list = list(set(data['univName'].tolist()))
for i in range(len(university_list)):
	if(len(data[data['univName'] == university_list[i]]) < 100):
		data = data[data['univName'] != university_list[i]]
data = data.dropna()

data.head()
# Out:
# C:\Users\saite\AppData\Local\Temp\ipykernel_18104\4000121458.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data = data.drop('major',1)
# C:\Users\saite\AppData\Local\Temp\ipykernel_18104\4000121458.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data = data.drop('program',1)
# C:\Users\saite\AppData\Local\Temp\ipykernel_18104\4000121458.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data = data.drop('season',1)
# C:\Users\saite\AppData\Local\Temp\ipykernel_18104\4000121458.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data = data.drop('decision',1)
# C:\Users\saite\AppData\Local\Temp\ipykernel_18104\4000121458.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data = data.drop('Method',1)
# C:\Users\saite\AppData\Local\Temp\ipykernel_18104\4000121458.py:6: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data = data.drop('decdate',1)
# C:\Users\saite\AppData\Local\Temp\ipykernel_18104\4000121458.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data = data.drop('decdate_ts',1)
# C:\Users\saite\AppData\Local\Temp\ipykernel_18104\4000121458.py:8: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data = data.drop('is_new_gre',1)
# C:\Users\saite\AppData\Local\Temp\ipykernel_18104\4000121458.py:9: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data = data.drop('gre_subject',1)
# C:\Users\saite\AppData\Local\Temp\ipykernel_18104\4000121458.py:10: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data = data.drop('status',1)
# C:\Users\saite\AppData\Local\Temp\ipykernel_18104\4000121458.py:11: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data = data.drop('post_data',1)
# C:\Users\saite\AppData\Local\Temp\ipykernel_18104\4000121458.py:12: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data = data.drop('post_timestamp',1)
# C:\Users\saite\AppData\Local\Temp\ipykernel_18104\4000121458.py:13: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data = data.drop('comments',1)
#                              univName  cgpa   greV   greQ  greA
# 14              Ohio State University  4.00  150.0  166.0   3.0
# 17               Texas A&M University  3.57  157.0  151.0   5.5
# 46   University Of California, Irvine  3.66  155.0  167.0   4.0
# 64                  Boston University  3.10  161.0  157.0   4.0
# 203           Oregon State University  3.38  154.0  170.0   4.0

# %%
processed_data = data[['greV', 'greQ', 'greA', 'cgpa', 'univName']]
processed_data.head()

processed_data.to_csv('Processed_data.csv')

# %%
import math
from sklearn import neighbors, datasets
from numpy.random import permutation
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_recall_fscore_support

# %%
#similar_univs = pandas.read_csv('similar_universities.csv')
random_indices = permutation(data.index)
test_cutoff = math.floor(len(data)/5)
print(test_cutoff)
test = processed_data.loc[random_indices[1:test_cutoff]]
train = processed_data.loc[random_indices[test_cutoff:]]
train_output_data = train['univName']
print("train Output data", train_output_data)
train_input_data = train
train_input_data = train_input_data.drop('univName',1)
print("train input data", train_input_data)
test_output_data = test['univName']
print("test Output data", test_output_data)
test_input_data = test
test_input_data = test_input_data.drop('univName',1)
print("test input data", test_input_data)
# Out:
# 5161
# train Output data 333746                        UC Berkeley
# 45484            University Of Pittsburgh
# 140887                 Cornell University
# 276849              Iowa State University
# 327161             University Of Michigan
#                        ...
# 316196             Stony Brook University
# 331325    University Of California, Davis
# 78940            University Of Pittsburgh
# 27881              University Of Virginia
# 41164              Wayne State University
# Name: univName, Length: 20647, dtype: object
# train input data          greV   greQ  greA  cgpa
# 333746  169.0  170.0   5.0  4.00
# 45484   160.0  154.0   5.5  3.71
# 140887  170.0  158.0   5.5  3.71
# 276849  157.0  170.0   0.0  3.76
# 327161  161.0  165.0   4.0  3.78
# ...       ...    ...   ...   ...
# 316196  148.0  170.0   3.5  3.80
# 331325  164.0  162.0   3.5  3.86
# 78940   147.0  170.0   4.0  3.60
# 27881   167.0  164.0   4.5  3.88
# 41164   149.0  147.0   4.0  3.70
#
# [20647 rows x 4 columns]
# test Output data 101057              University Of Michigan, Ann Arbor
# 322715                                    UC Berkeley
# 253542                       University Of Notre Dame
# 211501                                Duke University
# 334101                        University Of Minnesota
#                              ...
# 145478    University Of Minnesota - Twin Cities (UMN)
# 362242                      The University Of Chicago
# 190108                          University Of Florida
# 130149                          University Of Houston
# 18937     University Of Californa, Los Angeles (UCLA)
# Name: univName, Length: 5160, dtype: object
# test input data               greV        greQ  greA  cgpa
# 101057  165.000000  160.000000   5.0  3.70
# 322715  163.000000  163.000000   4.0  3.94
# 253542  157.000000  159.000000   4.0  3.36
# 211501  157.000000  168.000000   4.0  3.90
# 334101  168.085106  148.936170   4.0  3.90
# ...            ...         ...   ...   ...
# 145478  152.000000  170.000000   4.0  3.80
# 362242  144.680851  170.212766   5.0  3.98
# 190108  160.000000  160.000000   4.0  3.80
# 130149  154.000000  161.000000   3.5  3.83
# 18937   169.000000  161.000000   4.5  3.50
#
# [5160 rows x 4 columns]
# C:\Users\saite\AppData\Local\Temp\ipykernel_18104\929880055.py:10: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   train_input_data = train_input_data.drop('univName',1)
# C:\Users\saite\AppData\Local\Temp\ipykernel_18104\929880055.py:15: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   test_input_data = test_input_data.drop('univName',1)

# %%
def euclideanDistance(data1, data2, length):
    distance = 0
    for x in range(length):
        distance += np.square(data1[x] - data2[x])
    return np.sqrt(distance)

def knn(trainingSet, testInstance, k):
    print(k)
    distances = {}
    sort = {}
    length = testInstance.shape[1]

    for x in range(len(trainingSet)):

        dist = euclideanDistance(testInstance, trainingSet.iloc[x], length)
        
        distances[x] = dist[0]

    sorted_d = sorted(distances.items(), key=lambda x: x[1])

 
    neighbors = []

    for x in range(k):
        neighbors.append(sorted_d[x][0])

    classVotes = {}

    for x in range(len(neighbors)):
        response = trainingSet.iloc[neighbors[x]][-1]
        if response in classVotes:
            classVotes[response] += 1
        else:
            classVotes[response] = 1

    sortedVotes = sorted(classVotes.items(), key=lambda x: x[1], reverse=True)
 
    return(sortedVotes, neighbors)

# %%
testSet = [[171, 171, 6.1, 3.6]]
test = pd.DataFrame(testSet)
test.shape
# Out:
# (1, 4)

# %%
k = 7

result,neigh= knn(processed_data, test, k)


list1 = []
list2 = []
for i in result:
    list1.append(i[0])
    list2.append(i[1])
for i in list1:
    print(i)
# Out:
# 7
# Harvard University
# Duke University
# Princeton University
# Rutgers University
# Cornell University
# The University Of Chicago

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=5)
neigh.fit(processed_data.iloc[:,0:4], data['univName'])

print(neigh.predict(test))
# Out:
# ['Cornell University']
# C:\Users\saite\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
